# %%
# !wget https://unicode.org/Public/cldr/36/keyboards.zip
# Out:
# --2020-02-10 16:35:26--  https://unicode.org/Public/cldr/36/keyboards.zip
# Resolving unicode.org (unicode.org)... 216.97.88.9
# Connecting to unicode.org (unicode.org)|216.97.88.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1362580 (1.3M) [application/zip]
# Saving to: ‘keyboards.zip’
#
# keyboards.zip       100%[===================>]   1.30M   920KB/s    in 1.4s
#
# 2020-02-10 16:35:28 (920 KB/s) - ‘keyboards.zip’ saved [1362580/1362580]

# %%
# !unzip keyboards.zip
# Out:
# Archive:  keyboards.zip
#    creating: keyboards/
#    creating: keyboards/android/
#    creating: keyboards/chromeos/
#    creating: keyboards/dtd/
#    creating: keyboards/osx/
#    creating: keyboards/und/
#    creating: keyboards/windows/
#   inflating: ICU-LICENSE
#   inflating: apache-license.txt
#   inflating: keyboards/.project
#   inflating: keyboards/android/_platform.xml
#   inflating: keyboards/android/af-t-k0-android-600dpi.xml
#   inflating: keyboards/android/af-t-k0-android-768dpi.xml
#   inflating: keyboards/android/af-t-k0-android.xml
#   inflating: keyboards/android/ar-t-k0-android-600dpi.xml
#   inflating: keyboards/android/ar-t-k0-android-768dpi.xml
#   inflating: keyboards/android/ar-t-k0-android.xml
#   inflating: keyboards/android/be-t-k0-android-600dpi.xml
#   inflating: keyboards/android/be-t-k0-android-768dpi.xml
#   inflating: keyboards/android/be-t-k0-android.xml
#   inflating: keyboards/android/bg-t-k0-android-600dpi.xml
# ...

# %%
# !rm unicode-license.txt readme.html ICU-LICENSE apache-license.txt keyboards.zip

# %%
# !rm -rf keyboards/android keyboards/chromeos keyboards/osx keyboards/und
